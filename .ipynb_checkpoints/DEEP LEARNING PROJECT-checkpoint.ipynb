# %% [markdown]
# #                EMOTION DETECTION MODEL USING CONVOLUTIONAL NEURAL                                                       NETWORK AND OPENCV

# %% [markdown]
# # Import Libraries

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
import os
from tensorflow import keras
from tensorflow.keras.preprocessing.image import load_img

# %% [markdown]
# # Display Images:
# plot the happy expression images using subplot.

# %%
picture_size=48
folder_path="C:/Users/hp/Desktop/Deep learning project/images/"

# %%
expression='happy'
plt.figure(figsize=(12,12))
for i in range(1,10,1):
    plt.subplot(3,3,i)
    img=load_img(folder_path+"train/"+expression+"/"+
                os.listdir(folder_path+"train/"+expression)[i],target_size=(picture_size,picture_size))
    plt.imshow(img)
plt.show()

# %% [markdown]
# # Import DeepLearning Libraries
#
# The Sequential class is a linear stack of neural network layers that can be used to build a deep learning model.
#
# The layers imported are Dense, Input, Dropout, GlobalAveragePooling2D, Flatten, Conv2D, BatchNormalization, Activation, and MaxPooling2D. These layers are building blocks used to construct a neural network.
#
# Adam optimizer, which is a popular optimization algorithm used to train deep learning models.
#
# ImageDataGenerator class, which is used to generate batches of tensor image data with real-time data augmentation.

# %%
from keras.models import Sequential
from keras.layers import Dense,Input,Dropout,GlobalAveragePooling2D,Flatten,Conv2D,BatchNormalization,Activation,MaxPooling2D
from keras.optimizers import Adam
from keras.preprocessing.image import ImageDataGenerator

# %% [markdown]
# # Initialize image data generator with rescaling

# %%
datagen_train=ImageDataGenerator(rescale=1./255)
datagen_val=ImageDataGenerator(rescale=1./255)

# %% [markdown]
# # Preprocess all test and train images
#
#
#
# The parameters used in flow_from_directory() are:
#
#
# target_size: A tuple that specifies the height and width of the images after they are resized. In this case, the images are resized to (picture_size,picture_size) pixels.
#
# color_mode: A string that specifies the color space of the images. "grayscale" indicates that the images are grayscale and have only one channel.
#
# batch_size: An integer that specifies the number of images in each batch. In this case, the batch size is set to 64.
#
# class_mode: A string that specifies the type of labels returned by the generator. "categorical" means that the labels are one-hot encoded categorical vectors.
#
# shuffle: A boolean that specifies whether to shuffle the order of the images in each epoch. In this case, shuffling is set to True in train data ,shuffle set to False in test data.

# %%
train_set=datagen_train.flow_from_directory(folder_path+"train",
                                            target_size=(picture_size,picture_size),
                                            color_mode="grayscale",
                                            batch_size=64,
                                            class_mode="categorical",
                                            shuffle=True)
test_set=datagen_val.flow_from_directory(folder_path+"validation",
                                         target_size=(picture_size,picture_size),
                                        color_mode="grayscale",
                                         batch_size=64,
                                         class_mode="categorical",
                                         shuffle=False)
# Out:
# Found 28821 images belonging to 7 classes.
# Found 7066 images belonging to 7 classes.

# %% [markdown]
# # Model Building
#
# The model consists of several layers, including Convolutional Layers, MaxPooling Layers, Dropout Layers, and Dense Layers.
#
# The input images to the model are grayscale images of size 48x48 pixels. The first layer is a convolutional layer with 32 filters, followed by another convolutional layer with 64 filters. These layers are followed by a max pooling layer, which reduces the spatial dimensions of the output feature maps.
#
# Next, there is a dropout layer, which helps prevent overfitting. The model then has another set of convolutional and max pooling layers with 128 filters, followed by another dropout layer.
#
# After these layers, the feature maps are flattened and passed through two fully connected (dense) layers, with the first one having 1024 neurons and a ReLU activation function. Another dropout layer is added after this dense layer to prevent overfitting.
#
# Finally, the output layer is a dense layer with 7 neurons and a softmax activation function, which outputs the probabilities of the input image belonging to each of the 7 emotions.
#
# The model is compiled with the categorical cross-entropy loss function, the Adam optimizer with a learning rate of 0.0001 and decay rate of 1e-6, and accuracy as the evaluation metric.

# %%
model=Sequential()

model.add(Conv2D(32,kernel_size=(3,3),activation="relu",input_shape=(48,48,1)))
model.add(Conv2D(64,kernel_size=(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Conv2D(128,kernel_size=(3,3),activation="relu",input_shape=(48,48,1)))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Conv2D(128,kernel_size=(3,3),activation="relu"))
model.add(MaxPooling2D(pool_size=(2,2)))
model.add(Dropout(0.25))

model.add(Flatten())
model.add(Dense(1024,activation="relu"))
model.add(Dropout(0.5))
model.add(Dense(7,activation="softmax"))

model.compile(loss="categorical_crossentropy",optimizer=Adam(lr=0.0001,decay=1e-6),metrics=["accuracy"])
# Out:
# C:\Users\hp\anaconda3\lib\site-packages\keras\optimizers\optimizer_v2\adam.py:117: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super().__init__(name, **kwargs)

# %% [markdown]
# # Train the neural network model

# %%
model_info=model.fit_generator(train_set,steps_per_epoch=28821//64,epochs=30,validation_data=test_set,
                              validation_steps=7066//64)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_5220\468170253.py:1: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   model_info=model.fit_generator(train_set,steps_per_epoch=28821//64,epochs=30,validation_data=test_set,
# Epoch 1/30
# 450/450 [==============================] - 445s 988ms/step - loss: 1.8136 - accuracy: 0.2488 - val_loss: 1.7467 - val_accuracy: 0.3044
# Epoch 2/30
# 450/450 [==============================] - 234s 519ms/step - loss: 1.6578 - accuracy: 0.3497 - val_loss: 1.5614 - val_accuracy: 0.4018
# Epoch 3/30
# 450/450 [==============================] - 240s 532ms/step - loss: 1.5449 - accuracy: 0.4044 - val_loss: 1.4817 - val_accuracy: 0.4339
# Epoch 4/30
# 450/450 [==============================] - 238s 528ms/step - loss: 1.4754 - accuracy: 0.4325 - val_loss: 1.4217 - val_accuracy: 0.4670
# Epoch 5/30
# 450/450 [==============================] - 242s 539ms/step - loss: 1.4178 - accuracy: 0.4616 - val_loss: 1.3627 - val_accuracy: 0.4784
# Epoch 6/30
# 450/450 [==============================] - 238s 528ms/step - loss: 1.3612 - accuracy: 0.4834 - val_loss: 1.3257 - val_accuracy: 0.4984
# Epoch 7/30
# 450/450 [==============================] - 239s 530ms/step - loss: 1.3180 - accuracy: 0.5028 - val_loss: 1.2766 - val_accuracy: 0.5159
# Epoch 8/30
# 450/450 [==============================] - 237s 528ms/step - loss: 1.2772 - accuracy: 0.5151 - val_loss: 1.2568 - val_accuracy: 0.5283
# Epoch 9/30
# 450/450 [==============================] - 234s 520ms/step - loss: 1.2388 - accuracy: 0.5289 - val_loss: 1.2282 - val_accuracy: 0.5352
# Epoch 10/30
# 450/450 [==============================] - 237s 527ms/step - loss: 1.2108 - accuracy: 0.5414 - val_loss: 1.2049 - val_accuracy: 0.5446
# Epoch 11/30
# 450/450 [==============================] - 238s 529ms/step - loss: 1.1797 - accuracy: 0.5546 - val_loss: 1.1881 - val_accuracy: 0.5557
# Epoch 12/30
# 450/450 [==============================] - 236s 523ms/step - loss: 1.1506 - accuracy: 0.5668 - val_loss: 1.1652 - val_accuracy: 0.5658
# Epoch 13/30
# 450/450 [==============================] - 236s 524ms/step - loss: 1.1228 - accuracy: 0.5782 - val_loss: 1.1603 - val_accuracy: 0.5632
# Epoch 14/30
# 450/450 [==============================] - 237s 527ms/step - loss: 1.0996 - accuracy: 0.5868 - val_loss: 1.1460 - val_accuracy: 0.5690
# Epoch 15/30
# 450/450 [==============================] - 239s 532ms/step - loss: 1.0779 - accuracy: 0.5929 - val_loss: 1.1324 - val_accuracy: 0.5804
# Epoch 16/30
# 450/450 [==============================] - 242s 537ms/step - loss: 1.0495 - accuracy: 0.6071 - val_loss: 1.1139 - val_accuracy: 0.5893
# Epoch 17/30
# 450/450 [==============================] - 239s 530ms/step - loss: 1.0248 - accuracy: 0.6165 - val_loss: 1.1199 - val_accuracy: 0.5828
# Epoch 18/30
# 450/450 [==============================] - 237s 527ms/step - loss: 1.0025 - accuracy: 0.6264 - val_loss: 1.1042 - val_accuracy: 0.5916
# Epoch 19/30
# 450/450 [==============================] - 236s 524ms/step - loss: 0.9825 - accuracy: 0.6339 - val_loss: 1.1148 - val_accuracy: 0.5888
# Epoch 20/30
# 450/450 [==============================] - 238s 529ms/step - loss: 0.9569 - accuracy: 0.6435 - val_loss: 1.0880 - val_accuracy: 0.5902
# Epoch 21/30
# 450/450 [==============================] - 238s 529ms/step - loss: 0.9330 - accuracy: 0.6549 - val_loss: 1.0806 - val_accuracy: 0.6009
# Epoch 22/30
# 450/450 [==============================] - 237s 526ms/step - loss: 0.9086 - accuracy: 0.6646 - val_loss: 1.0781 - val_accuracy: 0.6020
# Epoch 23/30
# 450/450 [==============================] - 238s 529ms/step - loss: 0.8838 - accuracy: 0.6732 - val_loss: 1.0710 - val_accuracy: 0.6068
# Epoch 24/30
# 450/450 [==============================] - 241s 535ms/step - loss: 0.8646 - accuracy: 0.6800 - val_loss: 1.0729 - val_accuracy: 0.6044
# Epoch 25/30
# 450/450 [==============================] - 245s 544ms/step - loss: 0.8381 - accuracy: 0.6895 - val_loss: 1.0677 - val_accuracy: 0.6112
# Epoch 26/30
# 450/450 [==============================] - 249s 553ms/step - loss: 0.8114 - accuracy: 0.7043 - val_loss: 1.0729 - val_accuracy: 0.6074
# Epoch 27/30
# 450/450 [==============================] - 240s 534ms/step - loss: 0.7908 - accuracy: 0.7106 - val_loss: 1.0642 - val_accuracy: 0.6094
# Epoch 28/30
# 450/450 [==============================] - 240s 532ms/step - loss: 0.7692 - accuracy: 0.7177 - val_loss: 1.0638 - val_accuracy: 0.6136
# Epoch 29/30
# 450/450 [==============================] - 241s 536ms/step - loss: 0.7495 - accuracy: 0.7267 - val_loss: 1.0714 - val_accuracy: 0.6114
# Epoch 30/30
# 450/450 [==============================] - 241s 536ms/step - loss: 0.7189 - accuracy: 0.7414 - val_loss: 1.0734 - val_accuracy: 0.6155

# %% [markdown]
# # Save model structure in json file

# %%
model_json = model.to_json()
with open("model.json", "w") as json_file:
    json_file.write(model_json)

# %% [markdown]
# # Save trained model weight in .h5 file

# %%
model.save_weights("model.h5")
